# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# Create a set of random latitude and longitude combinations.
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_description = city_weather['weather'][0]['description']    
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | lima
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | zyryanka
# Processing Record 10 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | hobyo
# Processing Record 14 of Set 1 | skowhegan
# Processing Record 15 of Set 1 | kulunda
# Processing Record 16 of Set 1 | fiumicino
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | harnosand
# Processing Record 20 of Set 1 | katsuura
# Processing Record 21 of Set 1 | petatlan
# Processing Record 22 of Set 1 | morristown
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | comacchio
# Processing Record 26 of Set 1 | pacific grove
# Processing Record 27 of Set 1 | arlit
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | kashi
# Processing Record 30 of Set 1 | hirara
# Processing Record 31 of Set 1 | ahipara
# Processing Record 32 of Set 1 | uchaly
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | clyde river
# Processing Record 35 of Set 1 | lazaro cardenas
# Processing Record 36 of Set 1 | rosarito
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | sawakin
# Processing Record 42 of Set 1 | veraval
# Processing Record 43 of Set 1 | bakel
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | auray
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | buturlino
# Processing Record 49 of Set 1 | alsfeld
# Processing Record 50 of Set 1 | antalaha
# Processing Record 1 of Set 2 | mocuba
# Processing Record 2 of Set 2 | aswan
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | ranong
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | north platte
# Processing Record 7 of Set 2 | saint george
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | sergeyevka
# Processing Record 10 of Set 2 | constitucion
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | kuytun
# Processing Record 14 of Set 2 | ziro
# Processing Record 15 of Set 2 | maniitsoq
# Processing Record 16 of Set 2 | moindou
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | champerico
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | khorramshahr
# Processing Record 24 of Set 2 | laguna
# Processing Record 25 of Set 2 | oistins
# Processing Record 26 of Set 2 | vila velha
# Processing Record 27 of Set 2 | mayo
# Processing Record 28 of Set 2 | tukrah
# Processing Record 29 of Set 2 | umea
# Processing Record 30 of Set 2 | pekin
# Processing Record 31 of Set 2 | talant
# Processing Record 32 of Set 2 | coquimbo
# Processing Record 33 of Set 2 | guaruja
# Processing Record 34 of Set 2 | hammerfest
# Processing Record 35 of Set 2 | whyalla
# Processing Record 36 of Set 2 | porto novo
# Processing Record 37 of Set 2 | ous
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | alofi
# Processing Record 42 of Set 2 | paso de los toros
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | makakilo city
# Processing Record 46 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | alta
# Processing Record 49 of Set 2 | mimongo
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | necochea
# Processing Record 5 of Set 3 | barcelona
# Processing Record 6 of Set 3 | saskylakh
# Processing Record 7 of Set 3 | paytug
# City not found. Skipping...
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | nanzhou
# Processing Record 10 of Set 3 | kahului
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | longyearbyen
# Processing Record 13 of Set 3 | kazachinskoye
# Processing Record 14 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 15 of Set 3 | kerepehi
# Processing Record 16 of Set 3 | vieste
# Processing Record 17 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | sovetskiy
# Processing Record 20 of Set 3 | pangoa
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | labuhan
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | naze
# Processing Record 25 of Set 3 | rovaniemi
# Processing Record 26 of Set 3 | norman wells
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | waipawa
# Processing Record 29 of Set 3 | camana
# Processing Record 30 of Set 3 | salinas
# Processing Record 31 of Set 3 | banjar
# Processing Record 32 of Set 3 | taoudenni
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | hermanus
# Processing Record 35 of Set 3 | sao filipe
# Processing Record 36 of Set 3 | chambar
# Processing Record 37 of Set 3 | tautira
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | dingle
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | fairbanks
# Processing Record 42 of Set 3 | villamontes
# Processing Record 43 of Set 3 | port macquarie
# Processing Record 44 of Set 3 | acapulco
# Processing Record 45 of Set 3 | nova olinda do norte
# Processing Record 46 of Set 3 | indiana
# Processing Record 47 of Set 3 | grindavik
# Processing Record 48 of Set 3 | pakokku
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | zhoucheng
# Processing Record 1 of Set 4 | bathsheba
# Processing Record 2 of Set 4 | hobart
# Processing Record 3 of Set 4 | isangel
# Processing Record 4 of Set 4 | kaina
# Processing Record 5 of Set 4 | bairiki
# Processing Record 6 of Set 4 | avera
# Processing Record 7 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 4 | beloha
# Processing Record 9 of Set 4 | banda aceh
# Processing Record 10 of Set 4 | jiamusi
# Processing Record 11 of Set 4 | katunino
# Processing Record 12 of Set 4 | killybegs
# Processing Record 13 of Set 4 | beringovskiy
# Processing Record 14 of Set 4 | hilo
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | luanda
# Processing Record 17 of Set 4 | viedma
# Processing Record 18 of Set 4 | mahebourg
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | cumpas
# Processing Record 22 of Set 4 | hidalgotitlan
# Processing Record 23 of Set 4 | prince albert
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 4 | agadez
# Processing Record 27 of Set 4 | sena madureira
# Processing Record 28 of Set 4 | geraldton
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | kuandian
# Processing Record 31 of Set 4 | nyurba
# Processing Record 32 of Set 4 | santa marinella
# Processing Record 33 of Set 4 | panlaitan
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | malente
# Processing Record 36 of Set 4 | dukat
# Processing Record 37 of Set 4 | cayhagan
# Processing Record 38 of Set 4 | inirida
# Processing Record 39 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 4 | namatanai
# Processing Record 41 of Set 4 | smithers
# Processing Record 42 of Set 4 | port lincoln
# Processing Record 43 of Set 4 | kargasok
# Processing Record 44 of Set 4 | arman
# Processing Record 45 of Set 4 | caravelas
# Processing Record 46 of Set 4 | chicama
# Processing Record 47 of Set 4 | maningrida
# Processing Record 48 of Set 4 | richards bay
# Processing Record 49 of Set 4 | kieta
# Processing Record 50 of Set 4 | honiara
# Processing Record 1 of Set 5 | lagoa
# Processing Record 2 of Set 5 | auki
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | sabha
# Processing Record 5 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 5 | haines junction
# Processing Record 7 of Set 5 | aklavik
# Processing Record 8 of Set 5 | yar-sale
# Processing Record 9 of Set 5 | arraial do cabo
# Processing Record 10 of Set 5 | tiarei
# Processing Record 11 of Set 5 | sabang
# Processing Record 12 of Set 5 | tezu
# Processing Record 13 of Set 5 | kurilsk
# Processing Record 14 of Set 5 | makasar
# Processing Record 15 of Set 5 | pitimbu
# Processing Record 16 of Set 5 | ribeira grande
# Processing Record 17 of Set 5 | evensk
# Processing Record 18 of Set 5 | trairi
# Processing Record 19 of Set 5 | bethel
# Processing Record 20 of Set 5 | primorsko-akhtarsk
# Processing Record 21 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | piacabucu
# Processing Record 24 of Set 5 | mana
# Processing Record 25 of Set 5 | najran
# Processing Record 26 of Set 5 | lufilufi
# Processing Record 27 of Set 5 | nikolskoye
# Processing Record 28 of Set 5 | jibuti
# Processing Record 29 of Set 5 | raja jang
# Processing Record 30 of Set 5 | nambucca heads
# Processing Record 31 of Set 5 | guerrero negro
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 5 | sioux lookout
# Processing Record 35 of Set 5 | ajdabiya
# Processing Record 36 of Set 5 | iqaluit
# Processing Record 37 of Set 5 | cruzeiro do sul
# Processing Record 38 of Set 5 | bitung
# Processing Record 39 of Set 5 | paris
# Processing Record 40 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 5 | marzuq
# Processing Record 42 of Set 5 | karpathos
# Processing Record 43 of Set 5 | finnsnes
# Processing Record 44 of Set 5 | vardo
# Processing Record 45 of Set 5 | san vicente
# Processing Record 46 of Set 5 | payo
# Processing Record 47 of Set 5 | souillac
# Processing Record 48 of Set 5 | khorixas
# Processing Record 49 of Set 5 | redmond
# Processing Record 50 of Set 5 | volovo
# Processing Record 1 of Set 6 | manacapuru
# Processing Record 2 of Set 6 | ergani
# Processing Record 3 of Set 6 | saint-augustin
# Processing Record 4 of Set 6 | xai-xai
# Processing Record 5 of Set 6 | khandyga
# Processing Record 6 of Set 6 | katangli
# Processing Record 7 of Set 6 | skegness
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | karlovo
# Processing Record 10 of Set 6 | hami
# Processing Record 11 of Set 6 | tortoli
# Processing Record 12 of Set 6 | nuuk
# Processing Record 13 of Set 6 | axim
# Processing Record 14 of Set 6 | okato
# Processing Record 15 of Set 6 | coihaique
# Processing Record 16 of Set 6 | kangaba
# Processing Record 17 of Set 6 | sitka
# Processing Record 18 of Set 6 | butaritari
# Processing Record 19 of Set 6 | tamahu
# Processing Record 20 of Set 6 | tabatinga
# Processing Record 21 of Set 6 | paamiut
# Processing Record 22 of Set 6 | magadan
# Processing Record 23 of Set 6 | luwingu
# Processing Record 24 of Set 6 | ketchikan
# Processing Record 25 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 26 of Set 6 | sechura
# Processing Record 27 of Set 6 | marsa matruh
# Processing Record 28 of Set 6 | consuegra
# Processing Record 29 of Set 6 | tsaratanana
# Processing Record 30 of Set 6 | tonj
# Processing Record 31 of Set 6 | galveston
# Processing Record 32 of Set 6 | novobirilyussy
# Processing Record 33 of Set 6 | gayny
# Processing Record 34 of Set 6 | donskoye
# Processing Record 35 of Set 6 | launceston
# Processing Record 36 of Set 6 | bodden town
# Processing Record 37 of Set 6 | balikpapan
# Processing Record 38 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 6 | haapiti
# Processing Record 40 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 6 | bengkulu
# Processing Record 42 of Set 6 | soe
# Processing Record 43 of Set 6 | suleja
# Processing Record 44 of Set 6 | shelbyville
# Processing Record 45 of Set 6 | nanortalik
# Processing Record 46 of Set 6 | san patricio
# Processing Record 47 of Set 6 | quelimane
# Processing Record 48 of Set 6 | ryotsu
# Processing Record 49 of Set 6 | fortuna
# Processing Record 50 of Set 6 | kavaratti
# Processing Record 1 of Set 7 | rimbey
# Processing Record 2 of Set 7 | carutapera
# Processing Record 3 of Set 7 | riyadh
# Processing Record 4 of Set 7 | kuching
# Processing Record 5 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 6 of Set 7 | koulamoutou
# Processing Record 7 of Set 7 | manta
# Processing Record 8 of Set 7 | yantal
# Processing Record 9 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 7 | balakhninskiy
# Processing Record 11 of Set 7 | vao
# Processing Record 12 of Set 7 | barcelos
# Processing Record 13 of Set 7 | sierpc
# Processing Record 14 of Set 7 | padang
# Processing Record 15 of Set 7 | burica
# City not found. Skipping...
# Processing Record 16 of Set 7 | morgan city
# Processing Record 17 of Set 7 | morondava
# Processing Record 18 of Set 7 | poya
# Processing Record 19 of Set 7 | ye
# City not found. Skipping...
# Processing Record 20 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 7 | aguimes
# Processing Record 22 of Set 7 | meulaboh
# Processing Record 23 of Set 7 | przhevalskoye
# Processing Record 24 of Set 7 | shagamu
# Processing Record 25 of Set 7 | yellowknife
# Processing Record 26 of Set 7 | chuy
# Processing Record 27 of Set 7 | ravar
# Processing Record 28 of Set 7 | marystown
# Processing Record 29 of Set 7 | bilma
# Processing Record 30 of Set 7 | santa cruz de la palma
# Processing Record 31 of Set 7 | key largo
# Processing Record 32 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 7 | victoria
# Processing Record 34 of Set 7 | te anau
# Processing Record 35 of Set 7 | vestmannaeyjar
# Processing Record 36 of Set 7 | arona
# Processing Record 37 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 7 | bolitoc
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | rusape
# Processing Record 41 of Set 7 | nieuw amsterdam
# Processing Record 42 of Set 7 | warmbad
# Processing Record 43 of Set 7 | uvat
# Processing Record 44 of Set 7 | liepaja
# Processing Record 45 of Set 7 | marovoay
# Processing Record 46 of Set 7 | san quintin
# Processing Record 47 of Set 7 | los llanos de aridane
# Processing Record 48 of Set 7 | hasaki
# Processing Record 49 of Set 7 | khingansk
# Processing Record 50 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 8 | cap malheureux
# Processing Record 2 of Set 8 | benguela
# Processing Record 3 of Set 8 | nabari
# Processing Record 4 of Set 8 | sakakah
# Processing Record 5 of Set 8 | thap than
# Processing Record 6 of Set 8 | sorland
# Processing Record 7 of Set 8 | high prairie
# Processing Record 8 of Set 8 | miajadas
# Processing Record 9 of Set 8 | qasigiannguit
# Processing Record 10 of Set 8 | matagami
# Processing Record 11 of Set 8 | quatre cocos
# Processing Record 12 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 8 | college
# Processing Record 14 of Set 8 | adrar
# Processing Record 15 of Set 8 | farah
# Processing Record 16 of Set 8 | gizo
# Processing Record 17 of Set 8 | bandarbeyla
# Processing Record 18 of Set 8 | acari
# Processing Record 19 of Set 8 | roebourne
# Processing Record 20 of Set 8 | pangnirtung
# Processing Record 21 of Set 8 | paita
# Processing Record 22 of Set 8 | talgar
# Processing Record 23 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 8 | progreso
# Processing Record 25 of Set 8 | tateyama
# Processing Record 26 of Set 8 | salvador
# Processing Record 27 of Set 8 | burnie
# Processing Record 28 of Set 8 | xichang
# Processing Record 29 of Set 8 | kholodnyy
# Processing Record 30 of Set 8 | tilichiki
# Processing Record 31 of Set 8 | lhokseumawe
# Processing Record 32 of Set 8 | faya
# Processing Record 33 of Set 8 | itaqui
# Processing Record 34 of Set 8 | elizabeth city
# Processing Record 35 of Set 8 | puerto madryn
# Processing Record 36 of Set 8 | flinders
# Processing Record 37 of Set 8 | komsomolskiy
# Processing Record 38 of Set 8 | esperance
# Processing Record 39 of Set 8 | stoicanesti
# Processing Record 40 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 41 of Set 8 | dhidhdhoo
# Processing Record 42 of Set 8 | bayir
# Processing Record 43 of Set 8 | voh
# Processing Record 44 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 45 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 8 | pochutla
# Processing Record 47 of Set 8 | muravlenko
# Processing Record 48 of Set 8 | octeville
# Processing Record 49 of Set 8 | sansai
# City not found. Skipping...
# Processing Record 50 of Set 8 | sucua
# Processing Record 1 of Set 9 | mariental
# Processing Record 2 of Set 9 | baiao
# Processing Record 3 of Set 9 | esmeraldas
# Processing Record 4 of Set 9 | severnyy
# Processing Record 5 of Set 9 | indramayu
# Processing Record 6 of Set 9 | chushan
# Processing Record 7 of Set 9 | lompoc
# Processing Record 8 of Set 9 | sivaki
# Processing Record 9 of Set 9 | goderich
# Processing Record 10 of Set 9 | puerto baquerizo moreno
# Processing Record 11 of Set 9 | vila franca do campo
# Processing Record 12 of Set 9 | mbandaka
# Processing Record 13 of Set 9 | zaysan
# Processing Record 14 of Set 9 | atar
# Processing Record 15 of Set 9 | vanavara
# Processing Record 16 of Set 9 | port augusta
# Processing Record 17 of Set 9 | phan thiet
# Processing Record 18 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 9 | qom
# Processing Record 20 of Set 9 | puri
# Processing Record 21 of Set 9 | bafq
# Processing Record 22 of Set 9 | bereda
# Processing Record 23 of Set 9 | marawi
# Processing Record 24 of Set 9 | klaksvik
# Processing Record 25 of Set 9 | husavik
# Processing Record 26 of Set 9 | loukhi
# Processing Record 27 of Set 9 | half moon bay
# Processing Record 28 of Set 9 | port hedland
# Processing Record 29 of Set 9 | belmonte
# Processing Record 30 of Set 9 | zapolyarnyy
# Processing Record 31 of Set 9 | grand gaube
# Processing Record 32 of Set 9 | gamba
# Processing Record 33 of Set 9 | stillwater
# Processing Record 34 of Set 9 | kulachi
# Processing Record 35 of Set 9 | khasan
# Processing Record 36 of Set 9 | luwuk
# Processing Record 37 of Set 9 | narsaq
# Processing Record 38 of Set 9 | ocampo
# Processing Record 39 of Set 9 | alpena
# Processing Record 40 of Set 9 | chapais
# Processing Record 41 of Set 9 | ancud
# Processing Record 42 of Set 9 | pisco
# Processing Record 43 of Set 9 | yerbogachen
# Processing Record 44 of Set 9 | ngunguru
# Processing Record 45 of Set 9 | hudson bay
# Processing Record 46 of Set 9 | bechyne
# Processing Record 47 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 9 | praya
# Processing Record 49 of Set 9 | vikulovo
# Processing Record 50 of Set 9 | ulaangom
# Processing Record 1 of Set 10 | mehran
# Processing Record 2 of Set 10 | chipata
# Processing Record 3 of Set 10 | naryan-mar
# Processing Record 4 of Set 10 | cayenne
# Processing Record 5 of Set 10 | bela
# Processing Record 6 of Set 10 | alice springs
# Processing Record 7 of Set 10 | saskatoon
# Processing Record 8 of Set 10 | inta
# Processing Record 9 of Set 10 | raudeberg
# Processing Record 10 of Set 10 | kaeo
# Processing Record 11 of Set 10 | bela vista
# Processing Record 12 of Set 10 | camacha
# Processing Record 13 of Set 10 | san cristobal
# Processing Record 14 of Set 10 | ustye
# Processing Record 15 of Set 10 | xiazhen
# Processing Record 16 of Set 10 | kokopo
# Processing Record 17 of Set 10 | kota tinggi
# Processing Record 18 of Set 10 | port-cartier
# Processing Record 19 of Set 10 | tocopilla
# Processing Record 20 of Set 10 | dourbali
# Processing Record 21 of Set 10 | aitape
# Processing Record 22 of Set 10 | anadyr
# Processing Record 23 of Set 10 | fomboni
# Processing Record 24 of Set 10 | salalah
# Processing Record 25 of Set 10 | biak
# Processing Record 26 of Set 10 | culebra
# Processing Record 27 of Set 10 | teofilo otoni
# Processing Record 28 of Set 10 | alekseyevskoye
# Processing Record 29 of Set 10 | ilmajoki
# Processing Record 30 of Set 10 | teahupoo
# Processing Record 31 of Set 10 | yanji
# Processing Record 32 of Set 10 | palmer
# Processing Record 33 of Set 10 | kandrian
# Processing Record 34 of Set 10 | lincoln
# Processing Record 35 of Set 10 | mayor pablo lagerenza
# Processing Record 36 of Set 10 | port-gentil
# Processing Record 37 of Set 10 | bedesa
# Processing Record 38 of Set 10 | srednekolymsk
# Processing Record 39 of Set 10 | kruisfontein
# Processing Record 40 of Set 10 | humberto de campos
# Processing Record 41 of Set 10 | innisfail
# Processing Record 42 of Set 10 | shingu
# Processing Record 43 of Set 10 | dajal
# Processing Record 44 of Set 10 | faanui
# Processing Record 45 of Set 10 | aurad
# Processing Record 46 of Set 10 | sao miguel do araguaia
# Processing Record 47 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 10 | yulara
# Processing Record 49 of Set 10 | starkville
# Processing Record 50 of Set 10 | lubango
# Processing Record 1 of Set 11 | pangai
# Processing Record 2 of Set 11 | muroto
# Processing Record 3 of Set 11 | yumen
# Processing Record 4 of Set 11 | vilyuysk
# Processing Record 5 of Set 11 | ambilobe
# Processing Record 6 of Set 11 | ironton
# Processing Record 7 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 11 | eirunepe
# Processing Record 9 of Set 11 | yaan
# Processing Record 10 of Set 11 | maceio
# Processing Record 11 of Set 11 | pemangkat
# Processing Record 12 of Set 11 | beisfjord
# Processing Record 13 of Set 11 | sur
# Processing Record 14 of Set 11 | kushima
# Processing Record 15 of Set 11 | umm kaddadah
# Processing Record 16 of Set 11 | uchiza
# Processing Record 17 of Set 11 | mountmellick
# Processing Record 18 of Set 11 | savonlinna
# Processing Record 19 of Set 11 | chingirlau
# Processing Record 20 of Set 11 | san policarpo
# Processing Record 21 of Set 11 | henties bay
# Processing Record 22 of Set 11 | noumea
# Processing Record 23 of Set 11 | balabac
# Processing Record 24 of Set 11 | lata
# Processing Record 25 of Set 11 | kaniama
# Processing Record 26 of Set 11 | verkhnevilyuysk
# Processing Record 27 of Set 11 | coromandel
# Processing Record 28 of Set 11 | itambacuri
# Processing Record 29 of Set 11 | karatau
# Processing Record 30 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 11 | alyangula
# Processing Record 32 of Set 11 | valparaiso
# Processing Record 33 of Set 11 | khuzhir
# Processing Record 34 of Set 11 | finschhafen
# Processing Record 35 of Set 11 | hofn
# Processing Record 36 of Set 11 | ifanadiana
# Processing Record 37 of Set 11 | nantucket
# Processing Record 38 of Set 11 | shahr-e kord
# Processing Record 39 of Set 11 | severo-kurilsk
# Processing Record 40 of Set 11 | kaifeng
# Processing Record 41 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 11 | bara
# Processing Record 43 of Set 11 | sulangan
# Processing Record 44 of Set 11 | hualmay
# Processing Record 45 of Set 11 | albanel
# Processing Record 46 of Set 11 | fort nelson
# Processing Record 47 of Set 11 | tura
# Processing Record 48 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 49 of Set 11 | maltahohe
# Processing Record 50 of Set 11 | jamame
# Processing Record 1 of Set 12 | begun
# Processing Record 2 of Set 12 | llanes
# Processing Record 3 of Set 12 | mehamn
# Processing Record 4 of Set 12 | sambava
# Processing Record 5 of Set 12 | soller
# Processing Record 6 of Set 12 | amahai
# Processing Record 7 of Set 12 | rio grande
# Processing Record 8 of Set 12 | saint-pierre
# Processing Record 9 of Set 12 | butembo
# Processing Record 10 of Set 12 | alto araguaia
# Processing Record 11 of Set 12 | solwezi
# Processing Record 12 of Set 12 | ust-kulom
# Processing Record 13 of Set 12 | inhambane
# Processing Record 14 of Set 12 | puntarenas
# Processing Record 15 of Set 12 | graham
# Processing Record 16 of Set 12 | indore
# Processing Record 17 of Set 12 | kanniyakumari
# Processing Record 18 of Set 12 | natal
# Processing Record 19 of Set 12 | sao gabriel da cachoeira
# Processing Record 20 of Set 12 | labytnangi
# Processing Record 21 of Set 12 | kalispell
# Processing Record 22 of Set 12 | thinadhoo
# Processing Record 23 of Set 12 | along
# Processing Record 24 of Set 12 | mengcheng
# Processing Record 25 of Set 12 | nome
# Processing Record 26 of Set 12 | severodvinsk
# Processing Record 27 of Set 12 | miri
# Processing Record 28 of Set 12 | kailua
# Processing Record 29 of Set 12 | gornyak
# Processing Record 30 of Set 12 | cabra
# Processing Record 31 of Set 12 | baraki barak
# Processing Record 32 of Set 12 | poronaysk
# Processing Record 33 of Set 12 | tomatlan
# Processing Record 34 of Set 12 | baruun-urt
# Processing Record 35 of Set 12 | hambantota
# Processing Record 36 of Set 12 | cuamba
# Processing Record 37 of Set 12 | collie
# Processing Record 38 of Set 12 | port hardy
# Processing Record 39 of Set 12 | aripuana
# Processing Record 40 of Set 12 | namibe
# Processing Record 41 of Set 12 | maniwaki
# Processing Record 42 of Set 12 | barra patuca
# Processing Record 43 of Set 12 | contai
# Processing Record 44 of Set 12 | matsusaka
# Processing Record 45 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 12 | muhos
# Processing Record 47 of Set 12 | trelew
# Processing Record 48 of Set 12 | san luis
# Processing Record 49 of Set 12 | alta floresta
# Processing Record 50 of Set 12 | cam ranh
# Processing Record 1 of Set 13 | goundi
# Processing Record 2 of Set 13 | port alberni
# Processing Record 3 of Set 13 | berlevag
# Processing Record 4 of Set 13 | les cayes
# Processing Record 5 of Set 13 | manbij
# Processing Record 6 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 7 of Set 13 | mezhdurechensk
# Processing Record 8 of Set 13 | kahramanmaras
# Processing Record 9 of Set 13 | ostrovnoy
# Processing Record 10 of Set 13 | elban
# Processing Record 11 of Set 13 | new waterford
# Processing Record 12 of Set 13 | jumla
# Processing Record 13 of Set 13 | havoysund
# Processing Record 14 of Set 13 | asau
# Processing Record 15 of Set 13 | tamandare
# Processing Record 16 of Set 13 | huallanca
# Processing Record 17 of Set 13 | song phi nong
# Processing Record 18 of Set 13 | tuatapere
# Processing Record 19 of Set 13 | zheshart
# Processing Record 20 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 21 of Set 13 | pansoy
# Processing Record 22 of Set 13 | orichi
# Processing Record 23 of Set 13 | madaoua
# Processing Record 24 of Set 13 | uinskoye
# Processing Record 25 of Set 13 | broome
# Processing Record 26 of Set 13 | sao jose da coroa grande
# Processing Record 27 of Set 13 | uruzgan
# Processing Record 28 of Set 13 | poum
# Processing Record 29 of Set 13 | labuan
# Processing Record 30 of Set 13 | hamilton
# Processing Record 31 of Set 13 | hinckley
# Processing Record 32 of Set 13 | korla
# Processing Record 33 of Set 13 | homnabad
# Processing Record 34 of Set 13 | angoram
# Processing Record 35 of Set 13 | pingliang
# Processing Record 36 of Set 13 | phalaborwa
# Processing Record 37 of Set 13 | deep river
# Processing Record 38 of Set 13 | teknaf
# Processing Record 39 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 13 | novokruchininskiy
# Processing Record 41 of Set 13 | batagay-alyta
# Processing Record 42 of Set 13 | ahuimanu
# Processing Record 43 of Set 13 | san joaquin
# Processing Record 44 of Set 13 | abu samrah
# Processing Record 45 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 46 of Set 13 | prenzlau
# Processing Record 47 of Set 13 | ivnya
# Processing Record 48 of Set 13 | tabora
# Processing Record 49 of Set 13 | san roque
# Processing Record 50 of Set 13 | humaita
# Processing Record 1 of Set 14 | igarka
# Processing Record 2 of Set 14 | maracas
# Processing Record 3 of Set 14 | raisio
# Processing Record 4 of Set 14 | nalut
# Processing Record 5 of Set 14 | muros
# Processing Record 6 of Set 14 | chara
# Processing Record 7 of Set 14 | mount isa
# Processing Record 8 of Set 14 | ladario
# Processing Record 9 of Set 14 | williams lake
# Processing Record 10 of Set 14 | aksarka
# Processing Record 11 of Set 14 | hay river
# Processing Record 12 of Set 14 | kendari
# Processing Record 13 of Set 14 | puerto rico
# Processing Record 14 of Set 14 | lively
# Processing Record 15 of Set 14 | tahoua
# Processing Record 16 of Set 14 | erzin
# Processing Record 17 of Set 14 | ilo
# Processing Record 18 of Set 14 | gejiu
# Processing Record 19 of Set 14 | owando
# Processing Record 20 of Set 14 | teeli
# Processing Record 21 of Set 14 | praia da vitoria
# Processing Record 22 of Set 14 | punta de bombon
# Processing Record 23 of Set 14 | barbacoas
# Processing Record 24 of Set 14 | galiakot
# Processing Record 25 of Set 14 | chipinge
# Processing Record 26 of Set 14 | claremorris
# Processing Record 27 of Set 14 | ucluelet
# Processing Record 28 of Set 14 | poddorye
# Processing Record 29 of Set 14 | kiruna
# Processing Record 30 of Set 14 | muzhi
# Processing Record 31 of Set 14 | altamont
# Processing Record 32 of Set 14 | puebloviejo
# Processing Record 33 of Set 14 | omboue
# Processing Record 34 of Set 14 | odweyne
# Processing Record 35 of Set 14 | margate
# Processing Record 36 of Set 14 | camargo
# Processing Record 37 of Set 14 | pueblo
# Processing Record 38 of Set 14 | bahia blanca
# Processing Record 39 of Set 14 | verkhnyaya inta
# Processing Record 40 of Set 14 | hollister
# Processing Record 41 of Set 14 | bonnyville
# Processing Record 42 of Set 14 | phetchaburi
# Processing Record 43 of Set 14 | boende
# Processing Record 44 of Set 14 | areia branca
# Processing Record 45 of Set 14 | eyl
# Processing Record 46 of Set 14 | montepuez
# Processing Record 47 of Set 14 | mount gambier
# Processing Record 48 of Set 14 | comodoro rivadavia
# Processing Record 49 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 14 | liverpool
# Processing Record 1 of Set 15 | taua
# Processing Record 2 of Set 15 | steamboat springs
# Processing Record 3 of Set 15 | zgierz
# Processing Record 4 of Set 15 | bundaberg
# Processing Record 5 of Set 15 | shimoda
# Processing Record 6 of Set 15 | dalbandin
# Processing Record 7 of Set 15 | cheney
# Processing Record 8 of Set 15 | huambo
# Processing Record 9 of Set 15 | senneterre
# Processing Record 10 of Set 15 | bud
# Processing Record 11 of Set 15 | majene
# Processing Record 12 of Set 15 | vwawa
# Processing Record 13 of Set 15 | jiazi
# Processing Record 14 of Set 15 | mpika
# Processing Record 15 of Set 15 | sorong
# Processing Record 16 of Set 15 | banff
# Processing Record 17 of Set 15 | ascension
# Processing Record 18 of Set 15 | garowe
# Processing Record 19 of Set 15 | sarangani
# Processing Record 20 of Set 15 | amzya
# Processing Record 21 of Set 15 | luklukan
# Processing Record 22 of Set 15 | rorvik
# Processing Record 23 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 24 of Set 15 | zhigansk
# Processing Record 25 of Set 15 | coahuayana
# Processing Record 26 of Set 15 | krasnokamensk
# Processing Record 27 of Set 15 | rio gallegos
# Processing Record 28 of Set 15 | iquique
# Processing Record 29 of Set 15 | oktyabrskiy
# Processing Record 30 of Set 15 | yining
# Processing Record 31 of Set 15 | lakes entrance
# Processing Record 32 of Set 15 | matara
# Processing Record 33 of Set 15 | awjilah
# Processing Record 34 of Set 15 | leshukonskoye
# Processing Record 35 of Set 15 | conde
# Processing Record 36 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 15 | angoche
# Processing Record 38 of Set 15 | kontagora
# Processing Record 39 of Set 15 | north battleford
# Processing Record 40 of Set 15 | turan
# Processing Record 41 of Set 15 | trincomalee
# Processing Record 42 of Set 15 | purace
# City not found. Skipping...
# Processing Record 43 of Set 15 | lavrentiya
# Processing Record 44 of Set 15 | nelson bay
# Processing Record 45 of Set 15 | nobeoka
# Processing Record 46 of Set 15 | kedougou
# Processing Record 47 of Set 15 | sept-iles
# Processing Record 48 of Set 15 | balkanabat
# Processing Record 49 of Set 15 | bouna
# Processing Record 50 of Set 15 | baraboo
# Processing Record 1 of Set 16 | sao felix do xingu
# Processing Record 2 of Set 16 | tumaco
# Processing Record 3 of Set 16 | zelenets
# Processing Record 4 of Set 16 | cherkasskoye
# Processing Record 5 of Set 16 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 6 of Set 16 | linhares
# Processing Record 7 of Set 16 | abu dhabi
# Processing Record 8 of Set 16 | imbituba
# Processing Record 9 of Set 16 | shenjiamen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 706

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Alfred -33.5906   26.8910     63.18        83          51
# 1          Lima -12.0432  -77.0282     73.90        62         100
# 2  Ponta Do Sol  32.6667  -17.1000     72.72        81          57
# 3        Albany  42.6001  -73.9662     48.02        46           1
# 4        Avarua -21.2078 -159.7750     73.45        78          40
# 5       Ushuaia -54.8000  -68.3000     48.76        65          64
# 6      Khatanga  71.9667  102.5000    -11.51       100         100
# 7      Zyryanka  65.7500  150.8500     -2.18        96         100
# 8   New Norfolk -42.7826  147.0587     62.10        91         100
# 9        Kodiak  57.7900 -152.4072     36.91        87         100
#
#    Wind Speed Country Current Description
# 0        7.00      ZA       broken clouds
# 1       12.66      PE     overcast clouds
# 2        4.68      PT       broken clouds
# 3        4.63      US           clear sky
# 4        9.22      CK    scattered clouds
# 5        6.53      AR          light rain
# 6        3.15      RU     overcast clouds
# 7        9.31      RU     overcast clouds
# 8        3.47      AU     overcast clouds
# 9       14.97      US          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Alfred      ZA -33.5906   26.8910     63.18        83          51
# 1          Lima      PE -12.0432  -77.0282     73.90        62         100
# 2  Ponta Do Sol      PT  32.6667  -17.1000     72.72        81          57
# 3        Albany      US  42.6001  -73.9662     48.02        46           1
# 4        Avarua      CK -21.2078 -159.7750     73.45        78          40
# 5       Ushuaia      AR -54.8000  -68.3000     48.76        65          64
# 6      Khatanga      RU  71.9667  102.5000    -11.51       100         100
# 7      Zyryanka      RU  65.7500  150.8500     -2.18        96         100
# 8   New Norfolk      AU -42.7826  147.0587     62.10        91         100
# 9        Kodiak      US  57.7900 -152.4072     36.91        87         100
#
#    Wind Speed Current Description
# 0        7.00       broken clouds
# 1       12.66     overcast clouds
# 2        4.68       broken clouds
# 3        4.63           clear sky
# 4        9.22    scattered clouds
# 5        6.53          light rain
# 6        3.15     overcast clouds
# 7        9.31     overcast clouds
# 8        3.47     overcast clouds
# 9       14.97          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
